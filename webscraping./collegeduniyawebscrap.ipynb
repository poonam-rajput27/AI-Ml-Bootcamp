# %%
import requests
from bs4 import BeautifulSoup
url="https://collegedunia.com/"
headers = {
'User-Agent': 'Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/109.0.0.0 Safari/537.36',
'Accept': 'text/html,application/xhtml+xml,application/xml;q=0.9,image/avif,image/webp,*/*;q=0.8',
'Accept-Language': 'en-US,en;q=0.9',
'Accept-Encoding': 'gzip, deflate, br',
'Referer': 'https://www.google.com/'
}

response = requests.get(url,headers=headers)

# %%
response.status_code
# Out:
# 200

# %%
soup=BeautifulSoup(response.content,"html.parser")
soup
# Out:
# <!DOCTYPE html>
# ...

# %%
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html lang="en">
#  <head>
#   <meta charset="utf-8"/>
#   <meta content="width=device-width, initial-scale=1,minimum-scale=1.0, maximum-scale=2.0, user-scalable=yes, shrink-to-fit=no,viewport-fit=cover" name="viewport"/>
#   <link as="image" class="jsx-4281398864 jsx-637017680" fetchpriority="high" href="https://image-static.collegedunia.com/public/images/cd_logo_dark_new.png" rel="preload"/>
#   <link as="image" class="jsx-4281398864 jsx-637017680" fetchpriority="high" href="https://image-static.collegedunia.com/public/images/cd_logo_white_new.png" rel="preload"/>
#   <link as="image" class="jsx-4281398864 jsx-637017680" fetchpriority="high" href="https://image-static.collegedunia.com/public/asset/sprite/common-header-sprite.svg" rel="preload"/>
#   <title>
#    Collegedunia: Top Colleges, Universities &amp; Institutes in India | Admission, Fees, Rankings of Top Management, Engineering, Medical Colleges
#   </title>
# ...

# %%
colleges = soup.find_all('div',class_='jsx-831255015')
print(colleges)
# Out:
# [<div class="jsx-831255015 jsx-2235380896 container"><h2 class="jsx-831255015 jsx-2235380896 heading">Top 10 Colleges</h2><div class="jsx-831255015 jsx-2235380896 selected-pill-container"><div class="jsx-831255015 jsx-2235380896 list-unstyled"><div class="slick-slider carousel-control top-colleges slick-initialized" dir="ltr"><button class="slick-arrow slick-prev slick-disabled" data-role="none" style="display:block" type="button"> <!-- -->Previous</button><div class="slick-list"><div class="slick-track" style="width:5000%;left:0%"><div aria-hidden="false" class="slick-slide slick-active slick-current" data-index="0" style="outline:none;width:0.5%" tabindex="-1"><div><button class="jsx-831255015 pill align-items-center" data-csm-title="BE/B.Tech" data-csm-track="true" data-event-type="link_click" data-ga-module="homepage" data-ga-section="Top 10 Colleges" data-ga-title="BE/B.Tech" data-ga-track="true" data-section_name="Top 10 Colleges" type="button">BE/B.Tech</button></div></div><di
# ...

# %%
college_data=[]

# %%
for college in colleges :
    title=college.find('div',class_='jsx-831255015 text-dark college-name')
    fee= college.find('div',class_='jsx-831255015 fees text-dark')
    rating=college.find('span',class_='jsx-831255015 text-dark rating')
    
    college_data.append(
        {
            'Title':title,
            'fee':fee,
            'rating':rating,
        }
        )

# %%
print(college_data)
# Out:
# [{'Title': <div class="jsx-831255015 text-dark college-name">IIT Delhi - Indian Institute of Technology [IITD]</div>, 'fee': <div class="jsx-831255015 fees text-dark">₹11,74,150</div>, 'rating': <span class="jsx-831255015 text-dark rating"><svg height="81.954" style="fill:#F8C100;width:15px;height:14.25px" viewbox="6.92 9.412 85.384 81.954" width="85.384" xml:space="preserve" xmlns="http://www.w3.org/2000/svg"><path d="M59.609 24.778c2.517 4.892 9.037 9.467 14.492 10.168l13.094 1.683c5.455.701 6.75 4.469 2.875 8.373l-9.301 9.369c-3.875 3.904-6.213 11.52-5.193 16.926l2.445 12.973c1.02 5.406-2.164 7.801-7.074 5.32l-11.784-5.949c-4.91-2.479-12.876-2.348-17.702.291l-11.582 6.336c-4.826 2.64-8.087.353-7.246-5.084l2.017-13.047c.841-5.437-1.745-12.972-5.747-16.746l-9.604-9.058c-4.002-3.774-2.833-7.582 2.597-8.462l13.031-2.113c5.43-.88 11.797-5.668 14.149-10.64l5.647-11.934c2.353-4.972 6.335-5.038 8.851-.146l6.035 11.74z"></path></svg><span class="jsx-831255015">5/5</span></span>}, {'Title':
# ...

# %%
import pandas as pd

# %%
data=pd.DataFrame(college_data)

# %%
print(data)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 print(data)
#
# NameError: name 'data' is not defined

# %%
if response.status_code==200:
 print(response.text)
# Out:
# <!DOCTYPE html><html lang="en"><head><meta charSet="utf-8"/><meta content="width=device-width, initial-scale=1,minimum-scale=1.0, maximum-scale=2.0, user-scalable=yes, shrink-to-fit=no,viewport-fit=cover" name="viewport"/><link as="image" fetchPriority="high" href="https://image-static.collegedunia.com/public/images/cd_logo_dark_new.png" rel="preload" class="jsx-4281398864 jsx-637017680"/><link as="image" fetchPriority="high" href="https://image-static.collegedunia.com/public/images/cd_logo_white_new.png" rel="preload" class="jsx-4281398864 jsx-637017680"/><link as="image" fetchPriority="high" href="https://image-static.collegedunia.com/public/asset/sprite/common-header-sprite.svg" rel="preload" class="jsx-4281398864 jsx-637017680"/><title>Collegedunia: Top Colleges, Universities &amp; Institutes in India | Admission, Fees, Rankings of Top Management, Engineering, Medical Colleges</title><meta name="description" content="Get Detailed Information on Top Colleges in India and Admission
# ...

# %%
data.to_csv("college_duniya_web_scraping", index=False)
