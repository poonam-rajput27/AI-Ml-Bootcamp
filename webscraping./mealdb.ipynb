# %% [markdown]
# <div style="padding: 35px 25px; background: linear-gradient(135deg, #f6fdfa 0%, #edf9f5 100%); border-left: 6px solid #48cfae; border-radius: 16px; border: 1px solid rgba(72, 207, 174, 0.2); box-shadow: 0 10px 25px rgba(72, 207, 174, 0.08); font-family: 'Segoe UI', system-ui, sans-serif; text-align: left; position: relative;"><div style="display: flex; justify-content: space-between; align-items: center; flex-wrap: wrap; gap: 10px;"><span style="background: linear-gradient(90deg, #48cfae, #36bc9b); color: #ffffff; padding: 5px 14px; border-radius: 20px; font-size: 0.75rem; font-weight: 600; text-transform: uppercase; letter-spacing: 1px; display: inline-block;">🍳 Culinary Pipeline</span><span style="font-family: 'Brush Script MT', 'cursive', sans-serif; color: #48cfae; font-size: 1.6rem; font-weight: 500;">By Poonam Rajput</span></div><h1 style="color: #1e3c35; margin: 18px 0 6px 0; font-size: 2.4rem; font-weight: 800; letter-spacing: -0.5px;">Data Extraction <span style="color: #48cfae; font-style: italic; font-weight: 700;">TheMealDB</span></h1><p style="color: #4a6c62; margin: 0 0 18px 0; font-size: 0.95rem; font-weight: 400; opacity: 0.9;">Harvesting Global Recipes. Analyzing Ingredients &amp; Culinary Categories.</p><div style="height: 1px; background: linear-gradient(90deg, rgba(72, 207, 174, 0.25), transparent); margin: 15px 0;"></div><div style="display: flex; gap: 20px; flex-wrap: wrap; font-size: 0.85rem; color: #3b5a52; font-weight: 600;"><span>🎯 <b>Target:</b> Recipes &amp; Ingredients</span><span>⚙️ <b>Engine:</b> HTTP Client / JSON Parser</span><span>📊 <b>Output:</b> Structured Recipe DataFrame</span></div></div>

# %% [markdown]
# <div style="padding: 15px 20px; background: linear-gradient(135deg, #f6fdfa 0%, #edf9f5 100%); border-left: 5px solid #48cfae; border-radius: 8px; border: 1px solid rgba(72, 207, 174, 0.2); font-family: 'Segoe UI', system-ui, sans-serif; text-align: left; display: flex; align-items: center; gap: 10px;"><span style="font-size: 1.2rem;">📦</span><span style="color: #1e3c35; font-size: 1.1rem; font-weight: 700; letter-spacing: -0.3px;">Importing <span style="color: #48cfae; font-style: italic;">Libraries</span></span></div>

# %%
import requests
import pandas as pd

# %% [markdown]
# <div style="padding: 15px 20px; background: linear-gradient(135deg, #f6fdfa 0%, #edf9f5 100%); border-left: 5px solid #48cfae; border-radius: 8px; border: 1px solid rgba(72, 207, 174, 0.2); font-family: 'Segoe UI', system-ui, sans-serif; text-align: left; display: flex; align-items: center; gap: 10px;"><span style="font-size: 1.2rem;">📦</span><span style="color: #1e3c35; font-size: 1.1rem; font-weight: 700; letter-spacing: -0.3px;">Send Request <span style="color: #48cfae; font-style: italic;"></span></span></div>

# %%
#BASE_URL = "https://www.themealdb.com/api/json/v1/1/random.php"
BASE_URL = "https://www.themealdb.com/api/json/v1/1/filter.php?c=Dessert"

def fetch_cookie_recipes():
    try:
        response = requests.get(BASE_URL, timeout=10)

        if response.status_code != 200:
            return {
                "success": False,
                "error": f"API failed with status {response.status_code}"
            }

        data = response.json()

        recipes = []

        if data["meals"]:
            for meal in data["meals"]:
                recipes.append({
                    "name": meal.get("strMeal"),
                    "category": meal.get("strCategory"),
                    "area": meal.get("strArea"),
                    "image": meal.get("strMealThumb")
                })

        return {
            "success": True,
            "recipes": recipes
        }

    except requests.exceptions.RequestException as e:
        return {
            "success": False,
            "error": str(e)}

# %% [markdown]
# <div style="padding: 15px 20px; background: linear-gradient(135deg, #f6fdfa 0%, #edf9f5 100%); border-left: 5px solid #48cfae; border-radius: 8px; border: 1px solid rgba(72, 207, 174, 0.2); font-family: 'Segoe UI', system-ui, sans-serif; text-align: left; display: flex; align-items: center; gap: 10px;"><span style="font-size: 1.2rem;"></span><span style="color: #1e3c35; font-size: 1.1rem; font-weight: 700; letter-spacing: -0.3px;">Extracting Data <span style="color: #48cfae; font-style: italic;"></span></span></div>

# %%
if __name__ == "__main__":
    result = fetch_cookie_recipes()
    print(result)
# Out:
# {'success': True, 'recipes': [{'name': 'Æbleskiver', 'category': None, 'area': 'Norway', 'image': 'https://www.themealdb.com/images/media/meals/wkhg581762773124.jpg'}, {'name': 'Alfajores', 'category': None, 'area': 'Argentina', 'image': 'https://www.themealdb.com/images/media/meals/a4kgf21763075288.jpg'}, {'name': 'Anzac biscuits', 'category': None, 'area': 'Australian', 'image': 'https://www.themealdb.com/images/media/meals/q47rkb1762324620.jpg'}, {'name': 'Apam balik', 'category': None, 'area': 'Malaysian', 'image': 'https://www.themealdb.com/images/media/meals/adxcbq1619787919.jpg'}, {'name': 'Apple & Blackberry Crumble', 'category': None, 'area': 'British', 'image': 'https://www.themealdb.com/images/media/meals/xvsurr1511719182.jpg'}, {'name': 'Apple cake', 'category': None, 'area': 'Netherlands', 'image': 'https://www.themealdb.com/images/media/meals/c0gmo31766594751.jpg'}, {'name': 'Apple Frangipan Tart', 'category': None, 'area': 'British', 'image': 'https://www.themealdb.com
# ...

# %% [markdown]
# <div style="padding: 15px 20px; background: linear-gradient(135deg, #f6fdfa 0%, #edf9f5 100%); border-left: 5px solid #48cfae; border-radius: 8px; border: 1px solid rgba(72, 207, 174, 0.2); font-family: 'Segoe UI', system-ui, sans-serif; text-align: left; display: flex; align-items: center; gap: 10px;"><span style="font-size: 1.2rem;"></span><span style="color: #1e3c35; font-size: 1.1rem; font-weight: 700; letter-spacing: -0.3px;"> <span style="color: #48cfae; font-style: italic;">/span></span></div>

# %%
df=pd.DataFrame( result)

# %%
df
# Out:
#      success                                            recipes
# 0       True  {'name': 'Æbleskiver', 'category': None, 'area...
# 1       True  {'name': 'Alfajores', 'category': None, 'area'...
# 2       True  {'name': 'Anzac biscuits', 'category': None, '...
# 3       True  {'name': 'Apam balik', 'category': None, 'area...
# 4       True  {'name': 'Apple & Blackberry Crumble', 'catego...
# ..       ...                                                ...
# 146     True  {'name': 'Vanilla alfajores', 'category': None...
# 147     True  {'name': 'Walnut Roll Gužvara', 'category': No...
# 148     True  {'name': 'Walnut, date & honey cake', 'categor...
# 149     True  {'name': 'White chocolate creme brulee', 'cate...
# 150     True  {'name': 'Zeeuwse bolussen', 'category': None,...
#
# [151 rows x 2 columns]
